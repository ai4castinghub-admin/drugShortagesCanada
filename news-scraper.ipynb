# %%
from GoogleNews import GoogleNews
import time
import pandas as pd

googlenews = GoogleNews(lang='en', region='Canada',encode='utf-8')
all_results=[]

googlenews = GoogleNews(lang='en', region='Canada',encode='utf-8',period='7d')
query = 'Drug Shortages in Canada'
googlenews.search(query)
time.sleep(7)

results= googlenews.results(sort=True)

for r in results:
  all_results.append({
      'title': r.get('title',''),
      'media': r.get('media',''),
      'desc': r.get('desc',''),
      'link': r.get('link',''),
      'pub_date': r.get('date','')
  })


temp = pd.DataFrame(all_results)
# Out:
# HTTP Error 429: Too Many Requests

# %%
import time
import random
from GoogleNews import GoogleNews
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io
import re
from datetime import datetime, timedelta
 
SHORTAGE_KEYWORDS = {
    "shortage", "out of stock", "supply issue", "unavailable",
    "backordered", "delayed", "scarcity", "running low", "supply disruption",
    "not available", "in limited supply", "distribution issue",
    "increased demand", "supply constraint", "hard to find"
}
 
def parse_google_date(date_str):
    try:
        return datetime.strptime(date_str, '%d %b %Y')
    except ValueError:
        match = re.match(r'(\d+)\s+(hour|day|week|month|year)s?\s+ago', date_str)
        if match:
            value, unit = int(match.group(1)), match.group(2)
            delta = {
                'hour': timedelta(hours=value),
                'day': timedelta(days=value),
                'week': timedelta(weeks=value),
                'month': timedelta(days=30 * value),
                'year': timedelta(days=365 * value),
            }.get(unit, timedelta(0))
            return datetime.today() - delta
       
        print('wrong datetime')
        return datetime.today()
 
def fetch_news_by_region(regions, start_year=2018, end_year=2025, max_pages=5):
    all_results = []
    
    for year in range(start_year, end_year + 1):
        start_date_str = f'01/01/{year}'
        end_date_str = f'12/31/{year}'
        print(f"\n===== Fetching for Year: {year} ({start_date_str} to {end_date_str}) =====")
        time.sleep(random.uniform(45, 60))

        for region in regions:
            #query = f"drug shortage medication shortage {region}"
            shortage_terms = ' OR '.join([f'"{kw}"' for kw in SHORTAGE_KEYWORDS])
            query = f'(drug OR medication) AND ({shortage_terms}) {region}'

            print(f"\nSearching: {query} | Year: {year} | Region: {region}")
            
            googlenews = GoogleNews(lang="en", region="CA")
            googlenews.set_time_range(start_date_str, end_date_str)
            googlenews.search(query)
            time.sleep(random.uniform(25, 40))

            for page in range(1, max_pages + 1):
                try:
                    googlenews.get_page(page)
                    results = googlenews.results(sort=True)
                    time.sleep(random.uniform(2, 5))
                except Exception as e:
                    print(f"Page {page} failed for {region} ({year}) | Error: {e}")
                    break

                if not results:
                    break  # stop if no results on this page

                for r in results:
                    pub_date = parse_google_date(r.get('date', ''))
                    all_results.append({
                        'region_search': region,
                        'year': year,
                        'title': r.get('title', ''),
                        'date': pub_date.date(),
                        'media': r.get('media', ''),
                        'desc': r.get('desc', ''),
                        'link': r.get('link', '')
                    })
                    
    return pd.DataFrame(all_results)


 
# --- All Canadian Provinces & Major Cities
regions = [
 
    "Ontario", "Quebec", "British Columbia", "Alberta", "Manitoba",
    "Saskatchewan", "Nova Scotia", "New Brunswick", "Newfoundland and Labrador",
    "Prince Edward Island", "Northwest Territories", "Yukon", "Nunavut",
 
    # "Toronto", "Vancouver", "Montreal", "Calgary", "Ottawa", "Edmonton",
    # "Winnipeg", "Halifax", "Quebec City", "Regina", "St. John's", "Victoria",
 
    "Canada"
]
 
 
df_region = fetch_news_by_region(regions)
df_region = df_region.sort_values(by='date', ascending=False)
df_region.drop_duplicates(subset="link", inplace=True, keep='last')
 
 
df_region.reset_index(drop=True, inplace=True)
 
def clean_google_news_url(url):
    if not isinstance(url, str):
        return url  
    for param in ['&ved=']: #, '&usg=', '&utm_'
        if param in url:
            url = url.split(param)[0]
    return url.rstrip('/')
 
df_region['link'] = df_region['link'].apply(clean_google_news_url)
 
df_region.to_csv('drug_shortage_news_info.csv', index=False)
# Out:
# ===== Fetching for Year: 2018 (01/01/2018 to 12/31/2018) =====
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Ontario | Year: 2018 | Region: Ontario
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Quebec | Year: 2018 | Region: Quebec
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") British Columbia | Year: 2018 | Region: British Columbia
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Alberta | Year: 2018 | Region: Alberta
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Manitoba | Year: 2018 | Region: Manitoba
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Saskatchewan | Year: 2018 | Region: Saskatchewan
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Nova Scotia | Year: 2018 | Region: Nova Scotia
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") New Brunswick | Year: 2018 | Region: New Brunswick
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Newfoundland and Labrador | Year: 2018 | Region: Newfoundland and Labrador
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Prince Edward Island | Year: 2018 | Region: Prince Edward Island
# '<' not supported between instances of 'datetime.datetime' and 'float'
# wrong datetime
# wrong datetime
# '<' not supported between instances of 'datetime.datetime' and 'float'
# wrong datetime
# wrong datetime
# wrong datetime
# '<' not supported between instances of 'datetime.datetime' and 'float'
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# '<' not supported between instances of 'datetime.datetime' and 'float'
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# '<' not supported between instances of 'datetime.datetime' and 'float'
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Northwest Territories | Year: 2018 | Region: Northwest Territories
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Yukon | Year: 2018 | Region: Yukon
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Nunavut | Year: 2018 | Region: Nunavut
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Canada | Year: 2018 | Region: Canada
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
# wrong datetime
#
# ===== Fetching for Year: 2019 (01/01/2019 to 12/31/2019) =====
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Ontario | Year: 2019 | Region: Ontario
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
#
# Searching: (drug OR medication) AND ("running low" OR "supply constraint" OR "backordered" OR "unavailable" OR "not available" OR "delayed" OR "increased demand" OR "supply issue" OR "out of stock" OR "hard to find" OR "shortage" OR "in limited supply" OR "supply disruption" OR "scarcity" OR "distribution issue") Quebec | Year: 2019 | Region: Quebec
# HTTP Error 429: Too Many Requests
